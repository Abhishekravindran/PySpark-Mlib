# %% [markdown]
# ## Overview
#
# This notebook will show you how to create and query a table or DataFrame that you uploaded to DBFS. [DBFS](https://docs.databricks.com/user-guide/dbfs-databricks-file-system.html) is a Databricks File System that allows you to store data for querying inside of Databricks. This notebook assumes that you have a file already inside of DBFS that you would like to read from.
#
# This notebook is written in **Python** so the default cell type is Python. However, you can use different languages by using the `%LANGUAGE` syntax. Python, Scala, SQL, and R are all supported.

# %%
# File location and type
file_location = "/FileStore/tables/tips-1.csv"
file_type = "csv"

df=spark.read.csv(file_location,header=True,inferSchema=True)
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+----+------+------+---+------+----+
# total_bill| tip|   sex|smoker|day|  time|size|
# +----------+----+------+------+---+------+----+
#      16.99|1.01|Female|    No|Sun|Dinner|   2|
#      10.34|1.66|  Male|    No|Sun|Dinner|   3|
#      21.01| 3.5|  Male|    No|Sun|Dinner|   3|
#      23.68|3.31|  Male|    No|Sun|Dinner|   2|
#      24.59|3.61|Female|    No|Sun|Dinner|   4|
#      25.29|4.71|  Male|    No|Sun|Dinner|   4|
#       8.77| 2.0|  Male|    No|Sun|Dinner|   2|
#      26.88|3.12|  Male|    No|Sun|Dinner|   4|
#      15.04|1.96|  Male|    No|Sun|Dinner|   2|
#      14.78|3.23|  Male|    No|Sun|Dinner|   2|
#      10.27|1.71|  Male|    No|Sun|Dinner|   2|
#      35.26| 5.0|Female|    No|Sun|Dinner|   4|
#      15.42|1.57|  Male|    No|Sun|Dinner|   2|
#      18.43| 3.0|  Male|    No|Sun|Dinner|   4|
#      14.83|3.02|Female|    No|Sun|Dinner|   2|
#      21.58|3.92|  Male|    No|Sun|Dinner|   2|
#      10.33|1.67|Female|    No|Sun|Dinner|   3|
#      16.29|3.71|  Male|    No|Sun|Dinner|   3|
#      16.97| 3.5|Female|    No|Sun|Dinner|   3|
#      20.65|3.35|  Male|    No|Sat|Dinner|   3|
# +----------+----+------+------+---+------+----+
# only showing top 20 rows
#
# </div>

# %%
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- total_bill: double (nullable = true)
# -- tip: double (nullable = true)
# -- sex: string (nullable = true)
# -- smoker: string (nullable = true)
# -- day: string (nullable = true)
# -- time: string (nullable = true)
# -- size: integer (nullable = true)
#
# </div>

# %%
df.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: [&#39;total_bill&#39;, &#39;tip&#39;, &#39;sex&#39;, &#39;smoker&#39;, &#39;day&#39;, &#39;time&#39;, &#39;size&#39;]</div>

# %%
#handling categorical Features
from pyspark.ml.feature import StringIndexer
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
indexer=StringIndexer(inputCols=['sex','day','time','smoker'],outputCols=['sex_indexed','day_indexed','time_indexed','smoker_indexed'])
df_r=indexer.fit(df).transform(df)
df_r.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+----+------+------+---+------+----+-----------+-----------+------------+--------------+
# total_bill| tip|   sex|smoker|day|  time|size|sex_indexed|day_indexed|time_indexed|smoker_indexed|
# +----------+----+------+------+---+------+----+-----------+-----------+------------+--------------+
#      16.99|1.01|Female|    No|Sun|Dinner|   2|        1.0|        1.0|         0.0|           0.0|
#      10.34|1.66|  Male|    No|Sun|Dinner|   3|        0.0|        1.0|         0.0|           0.0|
#      21.01| 3.5|  Male|    No|Sun|Dinner|   3|        0.0|        1.0|         0.0|           0.0|
#      23.68|3.31|  Male|    No|Sun|Dinner|   2|        0.0|        1.0|         0.0|           0.0|
#      24.59|3.61|Female|    No|Sun|Dinner|   4|        1.0|        1.0|         0.0|           0.0|
#      25.29|4.71|  Male|    No|Sun|Dinner|   4|        0.0|        1.0|         0.0|           0.0|
#       8.77| 2.0|  Male|    No|Sun|Dinner|   2|        0.0|        1.0|         0.0|           0.0|
#      26.88|3.12|  Male|    No|Sun|Dinner|   4|        0.0|        1.0|         0.0|           0.0|
#      15.04|1.96|  Male|    No|Sun|Dinner|   2|        0.0|        1.0|         0.0|           0.0|
#      14.78|3.23|  Male|    No|Sun|Dinner|   2|        0.0|        1.0|         0.0|           0.0|
#      10.27|1.71|  Male|    No|Sun|Dinner|   2|        0.0|        1.0|         0.0|           0.0|
#      35.26| 5.0|Female|    No|Sun|Dinner|   4|        1.0|        1.0|         0.0|           0.0|
#      15.42|1.57|  Male|    No|Sun|Dinner|   2|        0.0|        1.0|         0.0|           0.0|
#      18.43| 3.0|  Male|    No|Sun|Dinner|   4|        0.0|        1.0|         0.0|           0.0|
#      14.83|3.02|Female|    No|Sun|Dinner|   2|        1.0|        1.0|         0.0|           0.0|
#      21.58|3.92|  Male|    No|Sun|Dinner|   2|        0.0|        1.0|         0.0|           0.0|
#      10.33|1.67|Female|    No|Sun|Dinner|   3|        1.0|        1.0|         0.0|           0.0|
#      16.29|3.71|  Male|    No|Sun|Dinner|   3|        0.0|        1.0|         0.0|           0.0|
#      16.97| 3.5|Female|    No|Sun|Dinner|   3|        1.0|        1.0|         0.0|           0.0|
#      20.65|3.35|  Male|    No|Sat|Dinner|   3|        0.0|        0.0|         0.0|           0.0|
# +----------+----+------+------+---+------+----+-----------+-----------+------------+--------------+
# only showing top 20 rows
#
# </div>

# %%
df_r.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: [&#39;total_bill&#39;,
#  &#39;tip&#39;,
#  &#39;sex&#39;,
#  &#39;smoker&#39;,
#  &#39;day&#39;,
#  &#39;time&#39;,
#  &#39;size&#39;,
#  &#39;sex_indexed&#39;,
#  &#39;day_indexed&#39;,
#  &#39;time_indexed&#39;,
#  &#39;smoker_indexed&#39;]</div>

# %%
from pyspark.ml.feature import VectorAssembler
assembler=VectorAssembler(inputCols=['tip','size','sex_indexed','day_indexed','time_indexed','smoker_indexed'],outputCol='independent_feature')
output=assembler.transform(df_r)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
output.select('independent_feature').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+
#  independent_feature|
# +--------------------+
# [1.01,2.0,1.0,1.0...|
# [1.66,3.0,0.0,1.0...|
# [3.5,3.0,0.0,1.0,...|
# [3.31,2.0,0.0,1.0...|
# [3.61,4.0,1.0,1.0...|
# [4.71,4.0,0.0,1.0...|
# [2.0,2.0,0.0,1.0,...|
# [3.12,4.0,0.0,1.0...|
# [1.96,2.0,0.0,1.0...|
# [3.23,2.0,0.0,1.0...|
# [1.71,2.0,0.0,1.0...|
# [5.0,4.0,1.0,1.0,...|
# [1.57,2.0,0.0,1.0...|
# [3.0,4.0,0.0,1.0,...|
# [3.02,2.0,1.0,1.0...|
# [3.92,2.0,0.0,1.0...|
# [1.67,3.0,1.0,1.0...|
# [3.71,3.0,0.0,1.0...|
# [3.5,3.0,1.0,1.0,...|
# (6,[0,1],[3.35,3.0])|
# +--------------------+
# only showing top 20 rows
#
# </div>

# %%
final_data=output.select('independent_feature','total_bill')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
final_data.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+----------+
#  independent_feature|total_bill|
# +--------------------+----------+
# [1.01,2.0,1.0,1.0...|     16.99|
# [1.66,3.0,0.0,1.0...|     10.34|
# [3.5,3.0,0.0,1.0,...|     21.01|
# [3.31,2.0,0.0,1.0...|     23.68|
# [3.61,4.0,1.0,1.0...|     24.59|
# [4.71,4.0,0.0,1.0...|     25.29|
# [2.0,2.0,0.0,1.0,...|      8.77|
# [3.12,4.0,0.0,1.0...|     26.88|
# [1.96,2.0,0.0,1.0...|     15.04|
# [3.23,2.0,0.0,1.0...|     14.78|
# [1.71,2.0,0.0,1.0...|     10.27|
# [5.0,4.0,1.0,1.0,...|     35.26|
# [1.57,2.0,0.0,1.0...|     15.42|
# [3.0,4.0,0.0,1.0,...|     18.43|
# [3.02,2.0,1.0,1.0...|     14.83|
# [3.92,2.0,0.0,1.0...|     21.58|
# [1.67,3.0,1.0,1.0...|     10.33|
# [3.71,3.0,0.0,1.0...|     16.29|
# [3.5,3.0,1.0,1.0,...|     16.97|
# (6,[0,1],[3.35,3.0])|     20.65|
# +--------------------+----------+
# only showing top 20 rows
#
# </div>

# %%
from pyspark.ml.regression import LinearRegression
train_dt,test_dt=final_data.randomSplit([0.75,0.25])
regressor=LinearRegression(featuresCol='independent_feature',labelCol='total_bill')
regressor=regressor.fit(train_dt)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
regressor.coefficients
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[17]: DenseVector([3.326, 2.8574, -1.6129, -0.0732, -1.2934, 1.8064])</div>

# %%
regressor.intercept
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[18]: 2.9560129298241913</div>

# %%
predict=regressor.evaluate(test_dt)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
predict.predictions.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+----------+------------------+
#  independent_feature|total_bill|        prediction|
# +--------------------+----------+------------------+
# (6,[0,1],[1.25,2.0])|     10.07|12.828262890486478|
# (6,[0,1],[1.45,2.0])|      9.55|13.493467334996144|
# (6,[0,1],[1.47,2.0])|     10.77|13.559987779447113|
# (6,[0,1],[1.75,2.0])|     17.82|14.491274001760644|
#  (6,[0,1],[2.0,2.0])|     12.69|15.322779557397727|
#  (6,[0,1],[2.0,2.0])|     13.37|15.322779557397727|
# (6,[0,1],[2.24,3.0])|     16.04| 18.97838598204776|
# (6,[0,1],[2.31,3.0])|     18.69|19.211207537626144|
# (6,[0,1],[3.18,2.0])|     19.82|19.247485780004755|
# (6,[0,1],[3.35,3.0])|     20.65|22.670270649076407|
# (6,[0,1],[3.76,2.0])|     18.24|21.176578669082787|
#  (6,[0,1],[4.3,2.0])|      21.7|22.972630669258884|
# (6,[0,1],[5.92,3.0])|     29.03| 31.21814776102562|
# [1.0,1.0,1.0,0.0,...|      7.25| 7.526541288381552|
# [1.0,1.0,1.0,0.0,...|      3.07| 9.332918436037072|
# [1.1,2.0,1.0,0.0,...|      12.9|12.522881749530342|
# [1.44,2.0,0.0,2.0...|      7.56|12.020382015117761|
# [1.5,2.0,0.0,1.0,...|     15.69|15.392916365583922|
# [1.5,2.0,1.0,2.0,...|     10.65|10.607088393241256|
# [1.56,2.0,0.0,1.0...|      9.94|13.786100551281304|
# +--------------------+----------+------------------+
# only showing top 20 rows
#
# </div>

# %%
predict.r2
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[22]: 0.5214933891151736</div>

# %%
regressor.save('spark.model')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql

/* Query the created temp table in a SQL cell */

select * from `tips-1_csv`
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# With this registered as a temp view, it will only be available to this particular notebook. If you'd like other users to be able to query this table, you can also create a table from the DataFrame.
# Once saved, this table will persist across cluster restarts as well as allow various users across different notebooks to query this data.
# To do so, choose your table name and uncomment the bottom line.

permanent_table_name = "tips-1_csv"

# df.write.format("parquet").saveAsTable(permanent_table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
